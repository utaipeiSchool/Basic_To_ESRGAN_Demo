# %%
from google.colab import drive
drive.mount('/content/drive')

# %%
import os
root_dir = "/content/drive/MyDrive/basic"
os.chdir(root_dir)
os.listdir()

# %%
# !rm -rf BasicSR
# !git clone https://github.com/xinntao/BasicSR.git
# %cd BasicSR
# Out:
# Cloning into 'BasicSR'...
# remote: Enumerating objects: 5924, done.
# remote: Total 5924 (delta 0), reused 0 (delta 0), pack-reused 5924 (from 1)
# Receiving objects: 100% (5924/5924), 4.14 MiB | 14.71 MiB/s, done.
# Resolving deltas: 100% (3757/3757), done.
# Updating files: 100% (303/303), done.
# /content/drive/MyDrive/basic/BasicSR

# %%
# Install pytorch
# !pip install torch torchvision

# Check torch and cuda versions
import torch
print('Torch Version: ', torch.__version__)
print('CUDA Version: ', torch.version.cuda)
print('CUDNN Version: ', torch.backends.cudnn.version())
print('CUDA Available:', torch.cuda.is_available())
# Out:
# ...
#    ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 363.4/363.4 MB 4.2 MB/s eta 0:00:00
# ...
#    ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 13.8/13.8 MB 120.7 MB/s eta 0:00:00
# ...
#    ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 24.6/24.6 MB 93.1 MB/s eta 0:00:00
# ...
#    ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 883.7/883.7 kB 57.8 MB/s eta 0:00:00
# ...
#    ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 664.8/664.8 MB 1.9 MB/s eta 0:00:00
# ...
#    ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 211.5/211.5 MB 5.7 MB/s eta 0:00:00
# ...
#    ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 56.3/56.3 MB 15.0 MB/s eta 0:00:00
# ...
#    ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 127.9/127.9 MB 7.1 MB/s eta 0:00:00
# ...
#    ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 207.5/207.5 MB 6.8 MB/s eta 0:00:00
# ...
#    ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 21.1/21.1 MB 106.2 MB/s eta 0:00:00
# ...
#   Attempting uninstall: nvidia-nvjitlink-cu12
#     Found existing installation: nvidia-nvjitlink-cu12 12.5.82
#     Uninstalling nvidia-nvjitlink-cu12-12.5.82:
# ...

# %%
import os
root_dir = "/content/drive/MyDrive/basic/BasicSR"
os.chdir(root_dir)
os.listdir()
# Out:
# ['.git',
#  '.github',
#  '.gitignore',
#  '.pre-commit-config.yaml',
#  '.readthedocs.yaml',
#  '.vscode',
#  'CITATION.cff',
#  'LICENSE.txt',
#  'LICENSE',
#  'MANIFEST.in',
#  'README.md',
#  'README_CN.md',
#  'VERSION',
#  'assets',
#  'basicsr',
#  'colab',
#  'datasets',
#  'docs',
#  'experiments',
#  'inference',
#  'options',
#  'requirements.txt',
#  'scripts',
#  'setup.cfg',
#  'setup.py',
#  'test_scripts',
#  'tests']

# %%
# Install requirements
# !pip install -r requirements.txt
# Install BasicSR without cuda extentions
# !python setup.py develop
# Out:
# ...
#      ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 46.8/46.8 kB 3.6 MB/s eta 0:00:00
# ...
#    ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 297.8/297.8 kB 14.8 MB/s eta 0:00:00
# ...
#    ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 5.5/5.5 MB 112.3 MB/s eta 0:00:00
# ...
#    ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 256.2/256.2 kB 24.5 MB/s eta 0:00:00
# ...
# /usr/local/lib/python3.11/dist-packages/setuptools/__init__.py:94: _DeprecatedInstaller: setuptools.installer and fetch_build_eggs are deprecated.
# !!
#
#         ********************************************************************************
#         Requirements should be satisfied by a PEP 517 installer.
#         If you are using pip, you can try `pip install --use-pep517`.
#         ********************************************************************************
#
# !!
#   dist.fetch_build_eggs(dist.setup_requires)
# running develop
# ...

# %%
# !python scripts/download_pretrained_models.py ESRGAN
# Out:
# ...
# Download 63.8 MB / 63.8 MB: 100% 2043/2043 [00:10<00:00, 197.62chunk/s]
# ...
# Download 63.8 MB / 63.8 MB: 100% 2043/2043 [00:07<00:00, 266.08chunk/s]

# %%
# !python scripts/data_preparation/download_datasets.py Set5
# !python scripts/data_preparation/download_datasets.py Set14
# !python scripts/data_preparation/download_datasets.py BSD100
# Out:
# Set5.zip already exist. Do you want to cover it? Y/N
# Y
# Covering Set5.zip to /content/drive/MyDrive/basic/BasicSR/datasets/Set5.zip
# Download 2.0 MB / 2.0 MB: 100% 65/65 [00:00<00:00, 1659.12chunk/s]
# Extract /content/drive/MyDrive/basic/BasicSR/datasets/Set5.zip to /content/drive/MyDrive/basic/BasicSR/datasets/Set5
# Move /content/drive/MyDrive/basic/BasicSR/datasets/Set5/Set5 to /content/drive/MyDrive/basic/BasicSR/datasets/Set5
# Traceback (most recent call last):
#   File "/content/drive/MyDrive/basic/BasicSR/scripts/data_preparation/download_datasets.py", line 72, in <module>
#     download_dataset(args.dataset, file_ids[args.dataset])
#   File "/content/drive/MyDrive/basic/BasicSR/scripts/data_preparation/download_datasets.py", line 42, in download_dataset
#     shutil.move(path, extracted_path)
#   File "/usr/lib/python3.11/shutil.py", line 851, in move
#     raise Error("Destination path '%s' already exists" % real_dst)
# ...

# %%
# !python basicsr/test.py -opt options/test/ESRGAN/test_ESRGAN_x4_woGT.yml
# Out:
# Disable distributed.
# Path already exists. Rename it to /content/BasicSR/results/ESRGAN_SRx4_DF2KOST_official_archived_20250418_114649
# 2025-04-18 11:46:49,643 INFO:
#                 ____                _       _____  ____
#                / __ ) ____ _ _____ (_)_____/ ___/ / __ \
#               / __  |/ __ `// ___// // ___/\__ \ / /_/ /
#              / /_/ // /_/ /(__  )/ // /__ ___/ // _, _/
#             /_____/ \__,_//____//_/ \___//____//_/ |_|
#      ______                   __   __                 __      __
#     / ____/____   ____   ____/ /  / /   __  __ _____ / /__   / /
#    / / __ / __ \ / __ \ / __  /  / /   / / / // ___// //_/  / /
#   / /_/ // /_/ // /_/ // /_/ /  / /___/ /_/ // /__ / /<    /_/
#   \____/ \____/ \____/ \____/  /_____/\____/ \___//_/|_|  (_)
#
# Version Information:
# 	BasicSR: 1.4.2
# 	PyTorch: 2.6.0+cu124
# 	TorchVision: 0.21.0+cu124
# 2025-04-18 11:46:49,644 INFO:
#   name: ESRGAN_SRx4_DF2KOST_official
#   model_type: ESRGANModel
#   scale: 4
# ...

# %%
import cv2
import glob
import numpy as np
import os
import torch

from basicsr.models.archs.rrdbnet_arch import RRDBNet

# configuration
model_path = 'experiments/pretrained_models/ESRGAN/ESRGAN_SRx4_DF2KOST_official-ff704c30.pth'
folder = 'datasets/Set14/LRbicx4'
device = 'cuda'

device = torch.device(device)

# set up model
model = RRDBNet(
    num_in_ch=3, num_out_ch=3, num_feat=64, num_block=23, num_grow_ch=32)
model.load_state_dict(torch.load(model_path)['params'], strict=True)
model.eval()
model = model.to(device)

os.makedirs('results/ESRGAN', exist_ok=True)
for idx, path in enumerate(sorted(glob.glob(os.path.join(folder, '*')))):
    imgname = os.path.splitext(os.path.basename(path))[0]
    print(idx, imgname)
    # read image
    img = cv2.imread(path, cv2.IMREAD_COLOR).astype(np.float32) / 255.
    img = torch.from_numpy(np.transpose(img[:, :, [2, 1, 0]],
                                        (2, 0, 1))).float()
    img = img.unsqueeze(0).to(device)
    # inference
    with torch.no_grad():
        output = model(img)
    # save image
    output = output.data.squeeze().float().cpu().clamp_(0, 1).numpy()
    output = np.transpose(output[[2, 1, 0], :, :], (1, 2, 0))
    output = (output * 255.0).round().astype(np.uint8)
    cv2.imwrite(f'results/ESRGAN/{imgname}_ESRGAN.png', output)
# Out:
# ---------------------------------------------------------------------------
# ModuleNotFoundError                       Traceback (most recent call last)
# <ipython-input-13-90b76dbfaa0f> in <cell line: 0>()
#       5 import torch
#       6
# ----> 7 from basicsr.models.archs.rrdbnet_arch import RRDBNet
#       8
#       9 # configuration
#
# ModuleNotFoundError: No module named 'basicsr.models.archs'
#
# ---------------------------------------------------------------------------
# NOTE: If your import is failing due to a missing package, you can
# manually install dependencies using either !pip or !apt.
#
# To view examples of installing some common dependencies, click the
# "Open Examples" button below.
# ---------------------------------------------------------------------------

# %%
# !wget https://github.com/xinntao/BasicSR/releases/download/v0.1.1/RRDB_ESRGAN_x4.pth -P experiments/pretrained_models/
# Out:
# --2025-06-01 03:52:28--  https://github.com/xinntao/BasicSR/releases/download/v0.1.1/RRDB_ESRGAN_x4.pth
# Resolving github.com (github.com)... 140.82.121.4
# Connecting to github.com (github.com)|140.82.121.4|:443... connected.
# HTTP request sent, awaiting response... 301 Moved Permanently
# Location: https://github.com/XPixelGroup/BasicSR/releases/download/v0.1.1/RRDB_ESRGAN_x4.pth [following]
# --2025-06-01 03:52:28--  https://github.com/XPixelGroup/BasicSR/releases/download/v0.1.1/RRDB_ESRGAN_x4.pth
# Reusing existing connection to github.com:443.
# HTTP request sent, awaiting response... 404 Not Found
# 2025-06-01 03:52:28 ERROR 404: Not Found.

# %%
import os
import shutil

base_dir = '/content/drive/MyDrive/basic/BasicSR/datasets/BSD100/image_SRF_4'
gt_dir = '/content/drive/MyDrive/basic/BasicSR/datasets/BSD100/image_SRF_4HR'
lq_dir = '/content/drive/MyDrive/basic/BasicSR/datasets/BSD100/image_SRF_4_LR'

os.makedirs(gt_dir, exist_ok=True)
os.makedirs(lq_dir, exist_ok=True)

for fname in os.listdir(base_dir):
    src_path = os.path.join(base_dir, fname)
    if '_HR.png' in fname:
        shutil.copy(src_path, os.path.join(gt_dir, fname))
    elif '_LR.png' in fname:
        shutil.copy(src_path, os.path.join(lq_dir, fname))

print("✅ 分類完成，HR 和 LR 已分開。")
# Out:
# ✅ 分類完成，HR 和 LR 已分開。

# %%
import os

# 改 HR 檔名：img_001_SRF_4_HR.png → img_001.png
hr_dir = '/content/drive/MyDrive/basic/BasicSR/datasets/BSD100/image_SRF_4_HR'
for fname in os.listdir(hr_dir):
    if fname.endswith('_HR.png'):
        new_name = fname.replace('_SRF_4_HR.png', '.png')
        os.rename(os.path.join(hr_dir, fname), os.path.join(hr_dir, new_name))

# 改 LR 檔名：img_001_SRF_4_LR.png → img_001.png
lq_dir = '/content/drive/MyDrive/basic/BasicSR/datasets/BSD100/image_SRF_4_LR'
for fname in os.listdir(lq_dir):
    if fname.endswith('_LR.png'):
        new_name = fname.replace('_SRF_4_LR.png', '.png')
        os.rename(os.path.join(lq_dir, fname), os.path.join(lq_dir, new_name))

print("✅ HR 和 LR 檔案名稱重命名完成")
# Out:
# ✅ HR 和 LR 檔案名稱重命名完成

# %%
# !python basicsr/train.py -opt options/train/ESRGAN/train_ESRGAN_BSD100_x4.yml
# Out:
# Disable distributed.
# Path already exists. Rename it to /content/drive/MyDrive/basic/BasicSR/experiments/052_ESRGAN_BSD100_quick_archived_20250601_050848
# Path already exists. Rename it to /content/drive/MyDrive/basic/BasicSR/tb_logger/052_ESRGAN_BSD100_quick_archived_20250601_050848
# 2025-06-01 05:08:48,344 INFO:
#                 ____                _       _____  ____
#                / __ ) ____ _ _____ (_)_____/ ___/ / __ \
#               / __  |/ __ `// ___// // ___/\__ \ / /_/ /
#              / /_/ // /_/ /(__  )/ // /__ ___/ // _, _/
#             /_____/ \__,_//____//_/ \___//____//_/ |_|
#      ______                   __   __                 __      __
#     / ____/____   ____   ____/ /  / /   __  __ _____ / /__   / /
#    / / __ / __ \ / __ \ / __  /  / /   / / / // ___// //_/  / /
#   / /_/ // /_/ // /_/ // /_/ /  / /___/ /_/ // /__ / /<    /_/
#   \____/ \____/ \____/ \____/  /_____/\____/ \___//_/|_|  (_)
#
# Version Information:
# 	BasicSR: 1.4.2
# ...

# %%
# !python basicsr/test.py -opt options/test/ESRGAN/test_ESRGAN_BSD_100.yml
# Out:
# Disable distributed.
# 2025-06-01 06:51:47,213 INFO:
#                 ____                _       _____  ____
#                / __ ) ____ _ _____ (_)_____/ ___/ / __ \
#               / __  |/ __ `// ___// // ___/\__ \ / /_/ /
#              / /_/ // /_/ /(__  )/ // /__ ___/ // _, _/
#             /_____/ \__,_//____//_/ \___//____//_/ |_|
#      ______                   __   __                 __      __
#     / ____/____   ____   ____/ /  / /   __  __ _____ / /__   / /
#    / / __ / __ \ / __ \ / __  /  / /   / / / // ___// //_/  / /
#   / /_/ // /_/ // /_/ // /_/ /  / /___/ /_/ // /__ / /<    /_/
#   \____/ \____/ \____/ \____/  /_____/\____/ \___//_/|_|  (_)
#
# Version Information:
# 	BasicSR: 1.4.2
# 	PyTorch: 2.6.0+cu124
# 	TorchVision: 0.21.0+cu124
# 2025-06-01 06:51:47,214 INFO:
#   name: ESRGAN_BSD100_quick
#   model_type: ESRGANModel
#   scale: 4
#   num_gpu: 1
#   manual_seed: 0
#   datasets:[
#     test_1:[
#       name: BSD100_test
#       type: SingleImageDataset
# ...

# %%
from PIL import Image
import matplotlib.pyplot as plt
import os

lr_dir = '/content/drive/MyDrive/basic/BasicSR/datasets/BSD100/image_SRF_4_LR'
sr_dir = '/content/drive/MyDrive/basic/BasicSR/results/ESRGAN_BSD100_quick/visualization/BSD100_test'

for i in range(1, 101):
    img_id = f'{i:03d}'  # 001 ~ 100
    lr_path = os.path.join(lr_dir, f'img_{img_id}.png')
    sr_path = os.path.join(sr_dir, f'img_{img_id}_ESRGAN_BSD100_quick.png')

    if not os.path.exists(lr_path) or not os.path.exists(sr_path):
        print(f"❗ 圖片不存在: {lr_path} 或 {sr_path}")
        continue

    lr = Image.open(lr_path)
    sr = Image.open(sr_path)

    plt.figure(figsize=(10, 4))
    plt.subplot(1, 2, 1)
    plt.imshow(lr)
    plt.title(f"LR Input - img_{img_id}")
    plt.axis('off')

    plt.subplot(1, 2, 2)
    plt.imshow(sr)
    plt.title("ESRGAN Output")
    plt.axis('off')

    plt.show()
# Out:
# Output hidden; open in https://colab.research.google.com to view.
